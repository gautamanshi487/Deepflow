# %% [markdown]
# # Predicting the Sale Price of Bulldozers using Machine Learning

# %% [markdown]
# ## Data Loading & Initial Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression

# %%
train = pd.read_csv('C:/Users/hp/Desktop/ML/Deepflow Project/Current data/Train.csv', low_memory=False, parse_dates=['saledate'])

# %% [markdown]
# When handling time series data, it’s important to extract as much information as possible from the time and date features. In our case, we work with the saledate column, converting it to datetime format and then deriving useful features like saleYear, saleMonth, saleDay, saleDayOfWeek, and saleDayOfYear. These enriched features help the model capture temporal patterns more effectively.

# %%
print(train.dtypes['saledate'])
# Out:
# object

# %%
train['saledate'] = pd.to_datetime(train['saledate'], format='mixed', dayfirst=True)

# %%
print(train.dtypes['saledate'])
# Out:
# datetime64[ns]

# %%
train.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate  ... Undercarriage_Pad_Width  \
# 0                      68.0       Low 2006-11-16  ...                     NaN
# 1                    4640.0       Low 2004-03-26  ...                     NaN
# 2                    2838.0      High 2004-02-26  ...                     NaN
# 3                    3486.0      High 2011-05-19  ...                     NaN
# 4                     722.0    Medium 2009-07-23  ...                     NaN
#
#   Stick_Length Thumb Pattern_Changer Grouser_Type Backhoe_Mounting Blade_Type  \
# 0          NaN   NaN             NaN          NaN              NaN        NaN
# 1          NaN   NaN             NaN          NaN              NaN        NaN
# 2          NaN   NaN             NaN          NaN              NaN        NaN
# 3          NaN   NaN             NaN          NaN              NaN        NaN
# 4          NaN   NaN             NaN          NaN              NaN        NaN
#
#   Travel_Controls Differential_Type Steering_Controls
# 0             NaN          Standard      Conventional
# 1             NaN          Standard      Conventional
# 2             NaN               NaN               NaN
# 3             NaN               NaN               NaN
# 4             NaN               NaN               NaN
#
# [5 rows x 53 columns]

# %%
train.isnull().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    258360
# UsageBand                   331486
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             137191
# fiModelSeries               344217
# fiModelDescriptor           329206
# ProductSize                 210775
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                296764
# Enclosure                      325
# Forks                       209048
# Pad_Type                    321991
# Ride_Control                252519
# Stick                       321991
# Transmission                217895
# Turbocharged                321991
# Blade_Extension             375906
# Blade_Width                 375906
# Enclosure_Type              375906
# Engine_Horsepower           375906
# Hydraulics                   80555
# Pushblock                   375906
# Ripper                      296988
# Scarifier                   375895
# Tip_Control                 375906
# Tire_Size                   306407
# Coupler                     187173
# Coupler_System              357667
# Grouser_Tracks              357763
# Hydraulics_Flow             357763
# Track_Type                  301972
# Undercarriage_Pad_Width     301253
# Stick_Length                301907
# Thumb                       301837
# Pattern_Changer             301907
# Grouser_Type                301972
# Backhoe_Mounting            322453
# Blade_Type                  321292
# Travel_Controls             321291
# Differential_Type           331714
# Steering_Controls           331756
# dtype: int64

# %% [markdown]
# ## Cleaning the Data in Preparation for Data Modelling

# %%
# Identify and drop columns with >90% missing values
high_missing_cols = [col for col in train.columns if train[col].isnull().mean() > 0.90]
train.drop(high_missing_cols, axis=1, inplace=True)

# %%
train.drop(["SalesID", "MachineID"], axis=1, inplace=True)

# %%
train.dtypes.value_counts()
# Out:
# object            37
# int64              4
# float64            2
# datetime64[ns]     1
# Name: count, dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401125 entries, 0 to 401124
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalePrice                 401125 non-null  int64
#  1   ModelID                   401125 non-null  int64
#  2   datasource                401125 non-null  int64
#  3   auctioneerID              380989 non-null  float64
#  4   YearMade                  401125 non-null  int64
#  5   MachineHoursCurrentMeter  142765 non-null  float64
#  6   UsageBand                 69639 non-null   object
#  7   saledate                  401125 non-null  datetime64[ns]
#  8   fiModelDesc               401125 non-null  object
#  9   fiBaseModel               401125 non-null  object
#  10  fiSecondaryDesc           263934 non-null  object
#  11  fiModelSeries             56908 non-null   object
#  12  fiModelDescriptor         71919 non-null   object
#  13  ProductSize               190350 non-null  object
#  14  fiProductClassDesc        401125 non-null  object
#  15  state                     401125 non-null  object
#  16  ProductGroup              401125 non-null  object
#  17  ProductGroupDesc          401125 non-null  object
#  18  Drive_System              104361 non-null  object
#  19  Enclosure                 400800 non-null  object
#  20  Forks                     192077 non-null  object
#  21  Pad_Type                  79134 non-null   object
#  22  Ride_Control              148606 non-null  object
#  23  Stick                     79134 non-null   object
#  24  Transmission              183230 non-null  object
#  25  Turbocharged              79134 non-null   object
#  26  Hydraulics                320570 non-null  object
#  27  Ripper                    104137 non-null  object
#  28  Tire_Size                 94718 non-null   object
#  29  Coupler                   213952 non-null  object
#  30  Coupler_System            43458 non-null   object
#  31  Grouser_Tracks            43362 non-null   object
#  32  Hydraulics_Flow           43362 non-null   object
#  33  Track_Type                99153 non-null   object
#  34  Undercarriage_Pad_Width   99872 non-null   object
#  35  Stick_Length              99218 non-null   object
#  36  Thumb                     99288 non-null   object
#  37  Pattern_Changer           99218 non-null   object
#  38  Grouser_Type              99153 non-null   object
#  39  Backhoe_Mounting          78672 non-null   object
#  40  Blade_Type                79833 non-null   object
#  41  Travel_Controls           79834 non-null   object
#  42  Differential_Type         69411 non-null   object
#  43  Steering_Controls         69369 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(37)
# memory usage: 134.7+ MB

# %%
train.head().T
# Out:
#                                                                  0  \
# SalePrice                                                    66000
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# saledate                                       2006-11-16 00:00:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# fiModelSeries                                                  NaN
# fiModelDescriptor                                              NaN
# ProductSize                                                    NaN
# fiProductClassDesc        Wheel Loader - 110.0 to 120.0 Horsepower
# state                                                      Alabama
# ProductGroup                                                    WL
# ProductGroupDesc                                      Wheel Loader
# Drive_System                                                   NaN
# Enclosure                                               EROPS w AC
# Forks                                          None or Unspecified
# Pad_Type                                                       NaN
# Ride_Control                                   None or Unspecified
# Stick                                                          NaN
# Transmission                                                   NaN
# Turbocharged                                                   NaN
# Hydraulics                                                 2 Valve
# Ripper                                                         NaN
# Tire_Size                                      None or Unspecified
# Coupler                                        None or Unspecified
# Coupler_System                                                 NaN
# Grouser_Tracks                                                 NaN
# Hydraulics_Flow                                                NaN
# Track_Type                                                     NaN
# Undercarriage_Pad_Width                                        NaN
# Stick_Length                                                   NaN
# Thumb                                                          NaN
# Pattern_Changer                                                NaN
# Grouser_Type                                                   NaN
# Backhoe_Mounting                                               NaN
# Blade_Type                                                     NaN
# Travel_Controls                                                NaN
# Differential_Type                                         Standard
# Steering_Controls                                     Conventional
#
#                                                                  1  \
# SalePrice                                                    57000
# ModelID                                                         77
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      1996
# MachineHoursCurrentMeter                                    4640.0
# UsageBand                                                      Low
# saledate                                       2004-03-26 00:00:00
# fiModelDesc                                                 950FII
# fiBaseModel                                                    950
# fiSecondaryDesc                                                  F
# fiModelSeries                                                   II
# fiModelDescriptor                                              NaN
# ProductSize                                                 Medium
# fiProductClassDesc        Wheel Loader - 150.0 to 175.0 Horsepower
# state                                               North Carolina
# ProductGroup                                                    WL
# ProductGroupDesc                                      Wheel Loader
# Drive_System                                                   NaN
# Enclosure                                               EROPS w AC
# Forks                                          None or Unspecified
# Pad_Type                                                       NaN
# Ride_Control                                   None or Unspecified
# Stick                                                          NaN
# Transmission                                                   NaN
# Turbocharged                                                   NaN
# Hydraulics                                                 2 Valve
# Ripper                                                         NaN
# Tire_Size                                                     23.5
# Coupler                                        None or Unspecified
# Coupler_System                                                 NaN
# Grouser_Tracks                                                 NaN
# Hydraulics_Flow                                                NaN
# Track_Type                                                     NaN
# Undercarriage_Pad_Width                                        NaN
# Stick_Length                                                   NaN
# Thumb                                                          NaN
# Pattern_Changer                                                NaN
# Grouser_Type                                                   NaN
# Backhoe_Mounting                                               NaN
# Blade_Type                                                     NaN
# Travel_Controls                                                NaN
# Differential_Type                                         Standard
# Steering_Controls                                     Conventional
#
#                                                                           2  \
# SalePrice                                                             10000
# ModelID                                                                7009
# datasource                                                              121
# auctioneerID                                                            3.0
# YearMade                                                               2001
# MachineHoursCurrentMeter                                             2838.0
# UsageBand                                                              High
# saledate                                                2004-02-26 00:00:00
# fiModelDesc                                                             226
# fiBaseModel                                                             226
# fiSecondaryDesc                                                         NaN
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Skid Steer Loader - 1351.0 to 1601.0 Lb Operat...
# state                                                              New York
# ProductGroup                                                            SSL
# ProductGroupDesc                                         Skid Steer Loaders
# Drive_System                                                            NaN
# Enclosure                                                             OROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                                NaN
# Ride_Control                                                            NaN
# Stick                                                                   NaN
# Transmission                                                            NaN
# Turbocharged                                                            NaN
# Hydraulics                                                        Auxiliary
# Ripper                                                                  NaN
# Tire_Size                                                               NaN
# Coupler                                                 None or Unspecified
# Coupler_System                                          None or Unspecified
# Grouser_Tracks                                          None or Unspecified
# Hydraulics_Flow                                                    Standard
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN
#
#                                                                           3  \
# SalePrice                                                             38500
# ModelID                                                                 332
# datasource                                                              121
# auctioneerID                                                            3.0
# YearMade                                                               2001
# MachineHoursCurrentMeter                                             3486.0
# UsageBand                                                              High
# saledate                                                2011-05-19 00:00:00
# fiModelDesc                                                        PC120-6E
# fiBaseModel                                                           PC120
# fiSecondaryDesc                                                         NaN
# fiModelSeries                                                           -6E
# fiModelDescriptor                                                       NaN
# ProductSize                                                           Small
# fiProductClassDesc        Hydraulic Excavator, Track - 12.0 to 14.0 Metr...
# state                                                                 Texas
# ProductGroup                                                            TEX
# ProductGroupDesc                                           Track Excavators
# Drive_System                                                            NaN
# Enclosure                                                        EROPS w AC
# Forks                                                                   NaN
# Pad_Type                                                                NaN
# Ride_Control                                                            NaN
# Stick                                                                   NaN
# Transmission                                                            NaN
# Turbocharged                                                            NaN
# Hydraulics                                                          2 Valve
# Ripper                                                                  NaN
# Tire_Size                                                               NaN
# Coupler                                                 None or Unspecified
# Coupler_System                                                          NaN
# Grouser_Tracks                                                          NaN
# Hydraulics_Flow                                                         NaN
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN
#
#                                                                           4
# SalePrice                                                             11000
# ModelID                                                               17311
# datasource                                                              121
# auctioneerID                                                            3.0
# YearMade                                                               2007
# MachineHoursCurrentMeter                                              722.0
# UsageBand                                                            Medium
# saledate                                                2009-07-23 00:00:00
# fiModelDesc                                                            S175
# fiBaseModel                                                            S175
# fiSecondaryDesc                                                         NaN
# fiModelSeries                                                           NaN
# fiModelDescriptor                                                       NaN
# ProductSize                                                             NaN
# fiProductClassDesc        Skid Steer Loader - 1601.0 to 1751.0 Lb Operat...
# state                                                              New York
# ProductGroup                                                            SSL
# ProductGroupDesc                                         Skid Steer Loaders
# Drive_System                                                            NaN
# Enclosure                                                             EROPS
# Forks                                                   None or Unspecified
# Pad_Type                                                                NaN
# Ride_Control                                                            NaN
# Stick                                                                   NaN
# Transmission                                                            NaN
# Turbocharged                                                            NaN
# Hydraulics                                                        Auxiliary
# Ripper                                                                  NaN
# Tire_Size                                                               NaN
# Coupler                                                 None or Unspecified
# Coupler_System                                          None or Unspecified
# Grouser_Tracks                                          None or Unspecified
# Hydraulics_Flow                                                    Standard
# Track_Type                                                              NaN
# Undercarriage_Pad_Width                                                 NaN
# Stick_Length                                                            NaN
# Thumb                                                                   NaN
# Pattern_Changer                                                         NaN
# Grouser_Type                                                            NaN
# Backhoe_Mounting                                                        NaN
# Blade_Type                                                              NaN
# Travel_Controls                                                         NaN
# Differential_Type                                                       NaN
# Steering_Controls                                                       NaN

# %%
# Sort DataFrame in date order
train.sort_values(by=["saledate"], inplace=True, ascending=True)
train.saledate.head()
# Out:
# 227861   1989-01-02
# 100964   1989-01-02
# 170025   1989-01-02
# 170009   1989-01-02
# 30354    1989-01-02
# Name: saledate, dtype: datetime64[ns]

# %%
# Add datetime parameters for saledate column
train["saleYear"] = train['saledate'].dt.year
train["saleMonth"] = train['saledate'].dt.month
train["saleDay"] = train['saledate'].dt.day
train["saleDayOfWeek"] = train['saledate'].dt.dayofweek
train["saleDayOfYear"] = train['saledate'].dt.dayofyear

# %%
train.head()
# Out:
#         SalePrice  ModelID  datasource  auctioneerID  YearMade  \
# 227861      36000     8899         132           4.0      1982
# 100964      23000     7261         132           4.0      1978
# 170025      18500     8247         132           4.0      1979
# 170009      20000     8247         132           4.0      1979
# 30354       22000     6788         132           4.0      1983
#
#         MachineHoursCurrentMeter UsageBand   saledate fiModelDesc fiBaseModel  \
# 227861                       NaN       NaN 1989-01-02        K909        K909
# 100964                       NaN       NaN 1989-01-02         920         920
# 170025                       NaN       NaN 1989-01-02         644         644
# 170009                       NaN       NaN 1989-01-02         644         644
# 30354                        NaN       NaN 1989-01-02         580         580
#
#         ... Backhoe_Mounting Blade_Type Travel_Controls Differential_Type  \
# 227861  ...              NaN        NaN             NaN               NaN
# 100964  ...              NaN        NaN             NaN          Standard
# 170025  ...              NaN        NaN             NaN          Standard
# 170009  ...              NaN        NaN             NaN          Standard
# 30354   ...              NaN        NaN             NaN               NaN
#
#        Steering_Controls saleYear saleMonth saleDay saleDayOfWeek  \
# 227861               NaN     1989         1       2             0
# 100964      Conventional     1989         1       2             0
# 170025      Conventional     1989         1       2             0
# 170009      Conventional     1989         1       2             0
# 30354                NaN     1989         1       2             0
#
#        saleDayOfYear
# 227861             2
# 100964             2
# 170025             2
# 170009             2
# 30354              2
#
# [5 rows x 49 columns]

# %%
train["saleYear"] = train.saledate.dt.year

# %%
print("saledate" in train.columns)
# Out:
# True

# %%
#After extracting useful datetime features, we remove the original 'saledate' column as it's no longer needed
train.drop("saledate", axis=1, inplace=True, errors='ignore')

# %%
print("saledate" in train.columns)
# Out:
# False

# %% [markdown]
# #### Make a copy of sorted and parsed dates DataFrame

# %%
train_1=train.copy()
train_1.to_csv('C:/Users/hp/Desktop/ML/Deepflow Project/Current data/train_1.csv', index=False)

# %% [markdown]
# #### List of all columns with missing data

# %%
train_1.columns[train_1.isnull().any()].tolist()
# Out:
# ['auctioneerID',
#  'MachineHoursCurrentMeter',
#  'UsageBand',
#  'fiSecondaryDesc',
#  'fiModelSeries',
#  'fiModelDescriptor',
#  'ProductSize',
#  'Drive_System',
#  'Enclosure',
#  'Forks',
#  'Pad_Type',
#  'Ride_Control',
#  'Stick',
#  'Transmission',
#  'Turbocharged',
#  'Hydraulics',
#  'Ripper',
#  'Tire_Size',
#  'Coupler',
#  'Coupler_System',
#  'Grouser_Tracks',
#  'Hydraulics_Flow',
#  'Track_Type',
#  'Undercarriage_Pad_Width',
#  'Stick_Length',
#  'Thumb',
#  'Pattern_Changer',
#  'Grouser_Type',
#  'Backhoe_Mounting',
#  'Blade_Type',
#  'Travel_Controls',
#  'Differential_Type',
#  'Steering_Controls']

# %%
# Check for missing values in train_1
train_1.isna().sum()[train_1.isna().sum()>0].sort_values(ascending=False)
# Out:
# Grouser_Tracks              357763
# Hydraulics_Flow             357763
# Coupler_System              357667
# fiModelSeries               344217
# Steering_Controls           331756
# Differential_Type           331714
# UsageBand                   331486
# fiModelDescriptor           329206
# Backhoe_Mounting            322453
# Stick                       321991
# Turbocharged                321991
# Pad_Type                    321991
# Blade_Type                  321292
# Travel_Controls             321291
# Tire_Size                   306407
# Grouser_Type                301972
# Track_Type                  301972
# Pattern_Changer             301907
# Stick_Length                301907
# Thumb                       301837
# Undercarriage_Pad_Width     301253
# Ripper                      296988
# Drive_System                296764
# MachineHoursCurrentMeter    258360
# Ride_Control                252519
# Transmission                217895
# ProductSize                 210775
# Forks                       209048
# Coupler                     187173
# fiSecondaryDesc             137191
# Hydraulics                   80555
# auctioneerID                 20136
# Enclosure                      325
# dtype: int64

# %% [markdown]
# ### Handling Missing Values in String Columns (Categorical)

# %% [markdown]
# #### Check which columns contain strings

# %%
string_col=train_1.select_dtypes(include=['object', 'string']).columns.tolist()
print(string_col)
# Out:
# ['UsageBand', 'fiModelDesc', 'fiBaseModel', 'fiSecondaryDesc', 'fiModelSeries', 'fiModelDescriptor', 'ProductSize', 'fiProductClassDesc', 'state', 'ProductGroup', 'ProductGroupDesc', 'Drive_System', 'Enclosure', 'Forks', 'Pad_Type', 'Ride_Control', 'Stick', 'Transmission', 'Turbocharged', 'Hydraulics', 'Ripper', 'Tire_Size', 'Coupler', 'Coupler_System', 'Grouser_Tracks', 'Hydraulics_Flow', 'Track_Type', 'Undercarriage_Pad_Width', 'Stick_Length', 'Thumb', 'Pattern_Changer', 'Grouser_Type', 'Backhoe_Mounting', 'Blade_Type', 'Travel_Controls', 'Differential_Type', 'Steering_Controls']

# %% [markdown]
# #### Convert the list of string values into categorical (numerical)

# %%
# This will turn all of the string values into category values
for col in string_col:
    train_1[col] = train_1[col].astype("category").cat.as_ordered()

# %%
# Get the encoded integer codes for the 'UsageBand' categorical column.Similarly get the encoded integer codes for the 'state' categorical column
train_1.UsageBand.cat.codes, train_1.state.cat.codes
# Out:
# (227861   -1
#  100964   -1
#  170025   -1
#  170009   -1
#  30354    -1
#           ..
#  396548   -1
#  400447   -1
#  397987   -1
#  400455   -1
#  400393   -1
#  Length: 401125, dtype: int8,
#  227861     8
#  100964     8
#  170025     8
#  170009     8
#  30354      8
#            ..
#  396548    31
#  400447    31
#  397987    31
#  400455    31
#  400393    31
#  Length: 401125, dtype: int8)

# %%
# All missing data in terms of percentages
train_1.isnull().sum()/len(train_1)
# Out:
# SalePrice                   0.000000
# ModelID                     0.000000
# datasource                  0.000000
# auctioneerID                0.050199
# YearMade                    0.000000
# MachineHoursCurrentMeter    0.644089
# UsageBand                   0.826391
# fiModelDesc                 0.000000
# fiBaseModel                 0.000000
# fiSecondaryDesc             0.342016
# fiModelSeries               0.858129
# fiModelDescriptor           0.820707
# ProductSize                 0.525460
# fiProductClassDesc          0.000000
# state                       0.000000
# ProductGroup                0.000000
# ProductGroupDesc            0.000000
# Drive_System                0.739829
# Enclosure                   0.000810
# Forks                       0.521154
# Pad_Type                    0.802720
# Ride_Control                0.629527
# Stick                       0.802720
# Transmission                0.543210
# Turbocharged                0.802720
# Hydraulics                  0.200823
# Ripper                      0.740388
# Tire_Size                   0.763869
# Coupler                     0.466620
# Coupler_System              0.891660
# Grouser_Tracks              0.891899
# Hydraulics_Flow             0.891899
# Track_Type                  0.752813
# Undercarriage_Pad_Width     0.751020
# Stick_Length                0.752651
# Thumb                       0.752476
# Pattern_Changer             0.752651
# Grouser_Type                0.752813
# Backhoe_Mounting            0.803872
# Blade_Type                  0.800977
# Travel_Controls             0.800975
# Differential_Type           0.826959
# Steering_Controls           0.827064
# saleYear                    0.000000
# saleMonth                   0.000000
# saleDay                     0.000000
# saleDayOfWeek               0.000000
# saleDayOfYear               0.000000
# dtype: float64

# %%
# Handle string columns in train_1
for label, content in train_1.items():
    if pd.api.types.is_string_dtype(content):
        # Optional: Track where the missing values were originally
        train_1[label + "_is_missing"] = content.isnull()
        # Convert to categorical and encode; missing values (-1) become 0 after +1
        train_1[label] = pd.Categorical(content).codes + 1

# %%
train_1.head().T
# Out:
#                              227861 100964 170025 170009 30354
# SalePrice                     36000  23000  18500  20000  22000
# ModelID                        8899   7261   8247   8247   6788
# datasource                      132    132    132    132    132
# auctioneerID                    4.0    4.0    4.0    4.0    4.0
# YearMade                       1982   1978   1979   1979   1983
# ...                             ...    ...    ...    ...    ...
# Backhoe_Mounting_is_missing    True   True   True   True   True
# Blade_Type_is_missing          True   True   True   True   True
# Travel_Controls_is_missing     True   True   True   True   True
# Differential_Type_is_missing   True  False  False  False   True
# Steering_Controls_is_missing   True  False  False  False   True
#
# [85 rows x 5 columns]

# %%
train_1.isnull().sum()/len(train_1)
# Out:
# SalePrice                       0.000000
# ModelID                         0.000000
# datasource                      0.000000
# auctioneerID                    0.050199
# YearMade                        0.000000
#                                   ...
# Backhoe_Mounting_is_missing     0.000000
# Blade_Type_is_missing           0.000000
# Travel_Controls_is_missing      0.000000
# Differential_Type_is_missing    0.000000
# Steering_Controls_is_missing    0.000000
# Length: 85, dtype: float64

# %%
train_2 = train_1.copy()
train_2.to_csv('C:/Users/hp/Desktop/ML/Deepflow Project/Current data/train_2.csv')

# %% [markdown]
# ### Handling Missing Values in Numerical Columns

# %% [markdown]
# #### Check for which numeric columns have null values

# %%
# List of numerical columns 
numeric_cols = train_1.select_dtypes(include=['int', 'float']).columns.tolist()

# %%
print(numeric_cols)
# Out:
# ['SalePrice', 'ModelID', 'datasource', 'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'saleYear', 'saleMonth', 'saleDay', 'saleDayOfWeek', 'saleDayOfYear']

# %%
# Check for which numeric columns have null values
numeric_na_cols=[col for col in train_1.select_dtypes(include=['int', 'float']).columns 
                   if train_1[col].isnull().any()]
print(numeric_na_cols)
# Out:
# ['auctioneerID', 'MachineHoursCurrentMeter']

# %% [markdown]
# #### Fill missing numeric values with median

# %%
# Handle missing numeric values in train_2
for label, content in train_2.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            # Add a binary column to indicate missing values
            train_2[label + "_is_missing"] = pd.isnull(content)
            # Fill missing values with median
            train_2[label] = content.fillna(content.median())

# %%
train_2.isna().sum()
# Out:
# SalePrice                              0
# ModelID                                0
# datasource                             0
# auctioneerID                           0
# YearMade                               0
#                                       ..
# Travel_Controls_is_missing             0
# Differential_Type_is_missing           0
# Steering_Controls_is_missing           0
# auctioneerID_is_missing                0
# MachineHoursCurrentMeter_is_missing    0
# Length: 87, dtype: int64

# %% [markdown]
#  #### Copy of data following data preparation and prior to data modelling stage.

# %%
train_3 = train_2.copy()
train_3.to_csv('C:/Users/hp/Desktop/ML/Deepflow Project/Current data/train_3.csv')

# %% [markdown]
# ## Upload TrainandValid and valid Dataset

# %%
tv = pd.read_csv('C:/Users/hp/Desktop/ML/Deepflow Project/Current data/TrainAndValid.csv'
, parse_dates=["saledate"], low_memory=False)

# %%
valid = pd.read_csv('C:/Users/hp/Desktop/ML/Deepflow Project/Current data/Valid.csv'
, parse_dates=["saledate"], low_memory=False)

# %% [markdown]
# ### preprocess() Function

# %%
import pandas as pd
import numpy as np

def preprocess(df):
    # 1. Convert saledate to datetime
    df['saledate'] = pd.to_datetime(df['saledate'], format='mixed', dayfirst=True)

    # 2. Extract date-related features
    df["saleYear"] = df['saledate'].dt.year
    df["saleMonth"] = df['saledate'].dt.month
    df["saleDay"] = df['saledate'].dt.day
    df["saleDayOfWeek"] = df['saledate'].dt.dayofweek
    df["saleDayOfYear"] = df['saledate'].dt.dayofyear

    # 3. Derived feature: machine age
    df['machine_age'] = df['saleYear'] - df['YearMade']

    # 4. Drop 'saledate' column
    df.drop(columns='saledate', inplace=True)

    # 5. Drop ID columns (if present)
    for id_col in ['SalesID', 'MachineID']:
        if id_col in df.columns:
            df.drop(id_col, axis=1, inplace=True)

    # 6. Drop columns with >90% missing values
    missing_ratio = df.isnull().mean()
    high_missing = missing_ratio[missing_ratio > 0.9].index
    print("Dropping highly missing columns:", high_missing.tolist())
    df.drop(high_missing, axis=1, inplace=True)

    # 7. Handle categorical columns (convert to ordered categories)
    string_cols = df.select_dtypes(include=['object', 'string']).columns.tolist()
    for col in string_cols:
        df[col] = df[col].astype("category").cat.as_ordered()

    # 8. Encode categorical variables and add _is_missing column
    for label, content in df.items():
        if pd.api.types.is_string_dtype(content) or isinstance(content.dtype, pd.CategoricalDtype):
            df[label + "_is_missing"] = pd.isnull(content)
            df[label] = pd.Categorical(content).codes + 1

    # 9. Handle numeric columns with missing values
    for label, content in df.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                df[label + "_is_missing"] = pd.isnull(content)
                df[label] = content.fillna(content.median())

    return df

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### 1.Linear Regression

# %%
tv = preprocess(tv)
valid = preprocess(valid)
# Out:
# Dropping highly missing columns: ['Blade_Extension', 'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Pushblock', 'Scarifier', 'Tip_Control']
# Dropping highly missing columns: ['Blade_Extension', 'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Pushblock', 'Scarifier', 'Tip_Control']

# %%
tv.isna().sum()
# Out:
# SalePrice                              0
# ModelID                                0
# datasource                             0
# auctioneerID                           0
# YearMade                               0
#                                       ..
# Travel_Controls_is_missing             0
# Differential_Type_is_missing           0
# Steering_Controls_is_missing           0
# auctioneerID_is_missing                0
# MachineHoursCurrentMeter_is_missing    0
# Length: 88, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# Split data into training and validation
# Split based on the year
df_val = tv[tv.saleYear == 2012]         # All data from 2012 → for validation
df_train = tv[tv.saleYear != 2012]       # All other years → for training
 
# Split into features (X) and labels (y)
X_train, y_train = df_train.drop("SalePrice", axis=1), df_train.SalePrice
X_valid, y_valid = df_val.drop("SalePrice", axis=1), df_val.SalePrice

# %%
y_valid.isna().sum()
# Out:
# 0

# %%
y_train.isna().sum()
# Out:
# 0

# %%
# Create the model
lin_reg = LinearRegression()

# Fit the model
lin_reg.fit(X_train, y_train)

# Predict
y_preds = lin_reg.predict(X_valid)

# %%
np.isnan(y_preds).sum()
# Out:
# 0

# %% [markdown]
# ### Calculating RMSLE as an Evaluation Function

# %% [markdown]
# #### Clip the negative predictions to 0 before calculating RMSLE

# %%
print("NaNs in predictions:", np.isnan(y_preds).sum())
print("Negatives in predictions:", (y_preds < 0).sum())
print("Min value in predictions:", y_preds.min())
# Out:
# NaNs in predictions: 0
# Negatives in predictions: 116
# Min value in predictions: -11002.421245754347

# %%
from sklearn.metrics import mean_squared_error

# Define RMSLE function
def rmsle(y_true, y_preds):
    # Clip negative predictions to 0
    y_preds = np.maximum(0, y_preds)
    return np.sqrt(mean_squared_error(np.log1p(y_true), np.log1p(y_preds)))

# Now compute score
rmsle_score = rmsle(y_valid, y_preds)
print(f"RMSLE: {rmsle_score:.4f}")
# Out:
# RMSLE: 1.0872

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_log_error, r2_score, mean_absolute_error
import numpy as np

# Step 1: Instantiate the model
model = RandomForestRegressor(n_jobs=-1,max_samples=10000, random_state=42)
# model = RandomForestRegressor(n_estimators=100, max_depth=None, max_samples=None, random_state=42)

# Step 2: Fit the model
model.fit(X_train, y_train)
# Out:
# CPU times: total: 1min 14s
# Wall time: 10.3 s
# RandomForestRegressor(max_samples=10000, n_jobs=-1, random_state=42)

# %%
# Step 3: RMSLE Function
def rmsle(y_true, y_preds):
    """
    Calculates Root Mean Squared Logarithmic Error (RMSLE)
    """
    return np.sqrt(mean_squared_log_error(y_true, y_preds))
    
# Step 4: Simplified Evaluation Function (RMSLE only)
def show_rmsle_scores(model):
    """
    Evaluate model using RMSLE on training and validation sets only.
    """
    train_preds = model.predict(X_train)
    val_preds = model.predict(X_valid)

    scores = {
        "Training RMSLE": round(rmsle(y_train, train_preds), 5),
        "Validation RMSLE": round(rmsle(y_valid, val_preds), 5)
    }
    return scores

# Step 5: Show only RMSLE scores
show_rmsle_scores(model)
# Out:
# {'Training RMSLE': 0.25307, 'Validation RMSLE': 0.28722}

# %% [markdown]
# # Make Predictions on Valid Data

# %%
# Load and preprocess validation data
valid_df = pd.read_csv(r"C:\Users\hp\Desktop\ML\Deepflow Project\Current data\Valid.csv", low_memory=False)
valid_df = preprocess(valid_df)
# Out:
# Dropping highly missing columns: ['Blade_Extension', 'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Pushblock', 'Scarifier', 'Tip_Control']

# %%
# Align valid_df_processed to training feature columns
valid_df_processed = valid_df.reindex(columns=X_train.columns, fill_value=0)

# %%
valid_preds = model.predict(valid_df_processed)

# %%
# Load original valid data again to get SalesID
valid_raw = pd.read_csv("valid.csv", low_memory=False)

submission_df = pd.DataFrame({
    "SalesID": valid_raw["SalesID"],
    "SalePrice": valid_preds
})
submission_df.to_csv("valid_predictions.csv", index=False)
print("Predictions saved to 'valid_predictions.csv'")
# Out:
# Predictions saved to 'valid_predictions.csv'

# %% [markdown]
# Check Rmlse Score

# %%
valid_solution = pd.read_csv(r"C:\Users\hp\Desktop\ML\Deepflow Project\Current data\ValidSolution.csv")

# %%
# Extract the true SalePrice values
y_valid_true = valid_solution['SalePrice']  # Adjust if the column name is different

# Make sure valid_preds and y_valid_true are aligned (same length)
print(len(valid_preds), len(y_valid_true))  # Should be equal
# Out:
# 11573 11573

# %%
score_valid = rmsle(y_valid_true, valid_preds)
print("Validation Score RMSLE:", round(score_valid, 5))
# Out:
# Validation Score RMSLE: 0.41222

# %% [markdown]
# # Make Predictions on Test Data

# %%
# STEP 1: Load and preprocess test data
test_df_raw = pd.read_csv('C:/Users/hp/Desktop/ML/Deepflow Project/Current data/Test.csv'
, low_memory=False)

# Save SalesID for later (as we dropped it during training)
test_ids = test_df_raw["SalesID"]
# Preprocess test data using the same function as training
test_df = preprocess(test_df_raw.copy())
test_ids = test_df_raw["SalesID"].copy()
# Out:
# Dropping highly missing columns: ['Blade_Extension', 'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Pushblock', 'Scarifier', 'Tip_Control']

# %%
# STEP 2: Ensure the test data has the same columns as training
# This is important because some columns may have been added during preprocessing (e.g., *_is_missing)
missing_cols = set(X_train.columns) - set(test_df.columns)
for col in missing_cols:
    test_df[col] = 0

# Also make sure column order matches
test_df = test_df[X_train.columns]

# %%
# STEP 3: Make predictions using your trained model
y_test_preds = model.predict(test_df)

# %%
# STEP 4: Create a submission DataFrame
submission_df = pd.DataFrame({
    "SalesID": test_ids,
    "SalePrice": y_test_preds
})

# %%
# STEP 5: Save to CSV
submission_df.to_csv("test_predictions.csv", index=False)
print(" Submission file saved as test_predictions.csv")
# Out:
#  Submission file saved as test_predictions.csv

# %%
test_predictions_true = pd.read_csv(r"C:\Users\hp\Desktop\ML\Deepflow Project\Current data\test_predictions_true.csv")

# %%
# Extract the true SalePrice values
y_test_true = test_predictions_true['SalesPrice']  # Adjust if the column name is different

# Make sure valid_preds and y_valid_true are aligned (same length)
print(len(y_test_preds), len(y_test_true))  # Should be equal
# Out:
# 12457 12457

# %%
score_test = rmsle(y_test_true, y_test_preds)
print("Test RMSLE:", round(score_test, 5))
# Out:
# Test RMSLE: 0.2978

# %%
# Basic info
print(test_df.info())
# Summary statistics
print(test_df.describe())
# Check for missing values
print(test_df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12457 entries, 0 to 12456
# Data columns (total 87 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ModelID                              12457 non-null  int64
#  1   datasource                           12457 non-null  int64
#  2   auctioneerID                         12457 non-null  int64
#  3   YearMade                             12457 non-null  int64
#  4   MachineHoursCurrentMeter             12457 non-null  float64
#  5   UsageBand                            12457 non-null  int8
#  6   fiModelDesc                          12457 non-null  int16
#  7   fiBaseModel                          12457 non-null  int16
#  8   fiSecondaryDesc                      12457 non-null  int8
#  9   fiModelSeries                        12457 non-null  int8
#  10  fiModelDescriptor                    12457 non-null  int8
#  11  ProductSize                          12457 non-null  int8
#  12  fiProductClassDesc                   12457 non-null  int8
#  13  state                                12457 non-null  int8
#  14  ProductGroup                         12457 non-null  int8
#  15  ProductGroupDesc                     12457 non-null  int8
#  16  Drive_System                         12457 non-null  int8
#  17  Enclosure                            12457 non-null  int8
#  18  Forks                                12457 non-null  int8
#  19  Pad_Type                             12457 non-null  int8
#  20  Ride_Control                         12457 non-null  int8
#  21  Stick                                12457 non-null  int8
#  22  Transmission                         12457 non-null  int8
#  23  Turbocharged                         12457 non-null  int8
#  24  Hydraulics                           12457 non-null  int8
#  25  Ripper                               12457 non-null  int8
#  26  Tire_Size                            12457 non-null  int8
#  27  Coupler                              12457 non-null  int8
#  28  Coupler_System                       12457 non-null  int8
#  29  Grouser_Tracks                       12457 non-null  int8
#  30  Hydraulics_Flow                      12457 non-null  int8
#  31  Track_Type                           12457 non-null  int8
#  32  Undercarriage_Pad_Width              12457 non-null  int8
#  33  Stick_Length                         12457 non-null  int8
#  34  Thumb                                12457 non-null  int8
#  35  Pattern_Changer                      12457 non-null  int8
#  36  Grouser_Type                         12457 non-null  int8
#  37  Backhoe_Mounting                     12457 non-null  int8
#  38  Blade_Type                           12457 non-null  int8
#  39  Travel_Controls                      12457 non-null  int8
#  40  Differential_Type                    12457 non-null  int8
#  41  Steering_Controls                    12457 non-null  int8
#  42  saleYear                             12457 non-null  int32
#  43  saleMonth                            12457 non-null  int32
#  44  saleDay                              12457 non-null  int32
#  45  saleDayOfWeek                        12457 non-null  int32
#  46  saleDayOfYear                        12457 non-null  int32
#  47  machine_age                          12457 non-null  int64
#  48  UsageBand_is_missing                 12457 non-null  bool
#  49  fiModelDesc_is_missing               12457 non-null  bool
#  50  fiBaseModel_is_missing               12457 non-null  bool
#  51  fiSecondaryDesc_is_missing           12457 non-null  bool
#  52  fiModelSeries_is_missing             12457 non-null  bool
#  53  fiModelDescriptor_is_missing         12457 non-null  bool
#  54  ProductSize_is_missing               12457 non-null  bool
#  55  fiProductClassDesc_is_missing        12457 non-null  bool
#  56  state_is_missing                     12457 non-null  bool
#  57  ProductGroup_is_missing              12457 non-null  bool
#  58  ProductGroupDesc_is_missing          12457 non-null  bool
#  59  Drive_System_is_missing              12457 non-null  bool
#  60  Enclosure_is_missing                 12457 non-null  bool
#  61  Forks_is_missing                     12457 non-null  bool
#  62  Pad_Type_is_missing                  12457 non-null  bool
#  63  Ride_Control_is_missing              12457 non-null  bool
#  64  Stick_is_missing                     12457 non-null  bool
#  65  Transmission_is_missing              12457 non-null  bool
#  66  Turbocharged_is_missing              12457 non-null  bool
#  67  Hydraulics_is_missing                12457 non-null  bool
#  68  Ripper_is_missing                    12457 non-null  bool
#  69  Tire_Size_is_missing                 12457 non-null  bool
#  70  Coupler_is_missing                   12457 non-null  bool
#  71  Coupler_System_is_missing            12457 non-null  bool
#  72  Grouser_Tracks_is_missing            12457 non-null  bool
#  73  Hydraulics_Flow_is_missing           12457 non-null  bool
#  74  Track_Type_is_missing                12457 non-null  bool
#  75  Undercarriage_Pad_Width_is_missing   12457 non-null  bool
#  76  Stick_Length_is_missing              12457 non-null  bool
#  77  Thumb_is_missing                     12457 non-null  bool
#  78  Pattern_Changer_is_missing           12457 non-null  bool
#  79  Grouser_Type_is_missing              12457 non-null  bool
#  80  Backhoe_Mounting_is_missing          12457 non-null  bool
#  81  Blade_Type_is_missing                12457 non-null  bool
#  82  Travel_Controls_is_missing           12457 non-null  bool
#  83  Differential_Type_is_missing         12457 non-null  bool
#  84  Steering_Controls_is_missing         12457 non-null  bool
#  85  auctioneerID_is_missing              12457 non-null  int64
#  86  MachineHoursCurrentMeter_is_missing  12457 non-null  bool
# dtypes: bool(38), float64(1), int16(2), int32(5), int64(6), int8(35)
# memory usage: 1.8 MB
# None
#             ModelID    datasource  auctioneerID      YearMade  \
# count  12457.000000  12457.000000  12457.000000  12457.000000
# mean    9221.484788    146.680019     11.924380   1868.981055
# std     7845.025382     14.158477     29.195676    338.095223
# min       28.000000    121.000000      0.000000   1000.000000
# 25%     3380.000000    149.000000      1.000000   1994.000000
# 50%     4886.000000    149.000000      1.000000   2002.000000
# 75%    15474.000000    149.000000      3.000000   2005.000000
# max    36941.000000    172.000000     99.000000   2014.000000
#
#        MachineHoursCurrentMeter     UsageBand   fiModelDesc   fiBaseModel  \
# count              1.245700e+04  12457.000000  12457.000000  12457.000000
# mean               6.314521e+03      0.344947    827.867304    315.694549
# std                2.781441e+05      0.868375    566.810097    231.904918
# min                0.000000e+00      0.000000      1.000000      1.000000
# 25%                3.525000e+03      0.000000    316.000000    122.000000
# 50%                3.525000e+03      0.000000    767.000000    259.000000
# 75%                3.525000e+03      0.000000   1273.000000    454.000000
# max                3.104628e+07      3.000000   1941.000000    831.000000
#
#        fiSecondaryDesc  fiModelSeries  ...  Travel_Controls  \
# count     12457.000000   12457.000000  ...     12457.000000
# mean         17.688769       5.938107  ...         0.744802
# std          17.663409      15.347917  ...         1.728147
# min           0.000000       0.000000  ...         0.000000
# 25%           0.000000       0.000000  ...         0.000000
# 50%          13.000000       0.000000  ...         0.000000
# 75%          25.000000       0.000000  ...         0.000000
# max          82.000000      63.000000  ...         6.000000
#
#        Differential_Type  Steering_Controls  saleYear     saleMonth  \
# count       12457.000000       12457.000000   12457.0  12457.000000
# mean            0.502448           0.338846    2012.0      7.401461
# std             1.115380           0.748512       0.0      2.360346
# min             0.000000           0.000000    2012.0      1.000000
# 25%             0.000000           0.000000    2012.0      6.000000
# 50%             0.000000           0.000000    2012.0      8.000000
# 75%             0.000000           0.000000    2012.0      9.000000
# max             3.000000           3.000000    2012.0     12.000000
#
#             saleDay  saleDayOfWeek  saleDayOfYear   machine_age  \
# count  12457.000000   12457.000000   12457.000000  12457.000000
# mean      17.226138       2.710524     211.992454    143.018945
# std        7.717443       1.460136      73.327347    338.095223
# min        5.000000       0.000000       5.000000     -2.000000
# 25%       10.000000       2.000000     166.000000      7.000000
# 50%       18.000000       3.000000     218.000000     10.000000
# 75%       24.000000       3.000000     269.000000     18.000000
# max       31.000000       6.000000     346.000000   1012.000000
#
#        auctioneerID_is_missing
# count                  12457.0
# mean                       0.0
# std                        0.0
# min                        0.0
# 25%                        0.0
# 50%                        0.0
# 75%                        0.0
# max                        0.0
#
# [8 rows x 49 columns]
# ModelID                                0
# datasource                             0
# auctioneerID                           0
# YearMade                               0
# MachineHoursCurrentMeter               0
#                                       ..
# Travel_Controls_is_missing             0
# Differential_Type_is_missing           0
# Steering_Controls_is_missing           0
# auctioneerID_is_missing                0
# MachineHoursCurrentMeter_is_missing    0
# Length: 87, dtype: int64

# %%
sns.histplot(test_preds, kde=True, color="y", bins=30)
plt.title("Distribution of Predicted SalePrice")
plt.xlabel("Predicted SalePrice")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Step 1: Get feature importances
feature_importances = model.feature_importances_
features = X_train.columns

# Step 2: Create DataFrame
feat_imp_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Step 3: Plot with larger fonts
plt.figure(figsize=(14, 10))
bars = plt.barh(feat_imp_df['Feature'][:20][::-1], feat_imp_df['Importance'][:20][::-1], color='skyblue')

plt.xlabel('Feature Importance', fontsize=14)
plt.ylabel('Features', fontsize=16)
plt.title('Top 20 Important Features in Random Forest Model', fontsize=18)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()
